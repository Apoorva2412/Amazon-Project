# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
off_rating = pd.read_csv("Office_rating.csv") 
off_rating
# Out:
#                asin      reviewerID  rating        date
# 0        0140503528  A2WJLOXXIB7NF3     3.0  2006-11-03
# 1        0140503528  A1RKICUK0GG6VF     5.0  2006-05-09
# 2        0140503528  A1QA5E50M398VW     5.0  2006-03-11
# 3        0140503528  A3N0HBW8IP8CZQ     5.0  2001-01-24
# 4        0140503528  A1K1JW1C5CUSUZ     5.0  2000-07-30
# ...             ...             ...     ...         ...
# 5396434  B01HJF6JIA  A1MZM2RPZNEAV7     5.0  2018-02-20
# 5396435  B01HJF6JIA  A3MY8HH0ZQDXIL     5.0  2017-12-19
# 5396436  B01HJF6JIA  A1FNE2AS2H4UCN     5.0  2017-10-12
# 5396437  B01HJF6JIA  A13K8XJJE5OWBJ     5.0  2017-10-11
# 5396438  B01HJF6JIA  A3IN62EIHVZY9N     1.0  2017-04-22
#
# [5396439 rows x 4 columns]

# %%
off_meta = pd.read_csv("Office_meta.csv") 
off_meta
# Out:
#                                                     title  \
# 0       Sequential Spelling Level 1 Bundle with Studen...
# 1       Mathematics, Applications and Concepts, Course...
# 2       Pearson MyHistoryLab Online Access Code for Am...
# 3                                   A Pocket for Corduroy
# 4       Social Entrepreneurship: What Everyone Needs t...
# ...                                                   ...
# 306612  Nintendo Super Mario Bros. Lanyard with Mario ...
# 306613  Lot of 2 - US American Flag &amp; Eagle US Pat...
# 306614  CatchTheWave Natural Wood Pen Holder Folding S...
# 306615  1pcs / Set Fashion Cartoon Blue Toy Story Phon...
# 306616  ( PACK OF 5 ) FELLOWSHIP Full Transparent Desi...
#
#                                                  also_buy  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# ...

# %%
off_merged = off_rating.merge(off_meta, how = 'left', on = 'asin')
off_merged
# Out:
#                asin      reviewerID  rating        date  \
# 0        0140503528  A2WJLOXXIB7NF3     3.0  2006-11-03
# 1        0140503528  A1RKICUK0GG6VF     5.0  2006-05-09
# 2        0140503528  A1QA5E50M398VW     5.0  2006-03-11
# 3        0140503528  A3N0HBW8IP8CZQ     5.0  2001-01-24
# 4        0140503528  A1K1JW1C5CUSUZ     5.0  2000-07-30
# ...             ...             ...     ...         ...
# 5396434  B01HJF6JIA  A1MZM2RPZNEAV7     5.0  2018-02-20
# 5396435  B01HJF6JIA  A3MY8HH0ZQDXIL     5.0  2017-12-19
# 5396436  B01HJF6JIA  A1FNE2AS2H4UCN     5.0  2017-10-12
# 5396437  B01HJF6JIA  A13K8XJJE5OWBJ     5.0  2017-10-11
# 5396438  B01HJF6JIA  A3IN62EIHVZY9N     1.0  2017-04-22
#
#                                                      title  \
# 0                                    A Pocket for Corduroy
# 1                                    A Pocket for Corduroy
# 2                                    A Pocket for Corduroy
# ...

# %%
off_merged.isnull().sum()
# Out:
# asin                      0
# reviewerID                0
# rating                    0
# date                      0
# title                  5117
# also_buy               4260
# brand                  4355
# rank                  42830
# also_view              4260
# main_cat               4260
# price               1434317
# primary_category       4260
# sub_cat                4260
# product_type           4260
# dtype: int64

# %%
off_merged = off_merged.dropna(subset = 'main_cat')
off_merged.isnull().sum()
# Out:
# asin                      0
# reviewerID                0
# rating                    0
# date                      0
# title                   857
# also_buy                  0
# brand                    95
# rank                  38570
# also_view                 0
# main_cat                  0
# price               1430057
# primary_category          0
# sub_cat                   0
# product_type              0
# dtype: int64

# %%
off_merged['title'] = off_merged['title'].fillna("Unknown")
off_merged['brand'] = off_merged['brand'].fillna(off_merged['brand'].mode()[0])
off_merged.isnull().sum()
# Out:
# asin                      0
# reviewerID                0
# rating                    0
# date                      0
# title                     0
# also_buy                  0
# brand                     0
# rank                  38570
# also_view                 0
# main_cat                  0
# price               1430057
# primary_category          0
# sub_cat                   0
# product_type              0
# dtype: int64

# %%
cds_rating = pd.read_csv("CdsVinyl_rating.csv") 
cds_rating
# Out:
#                asin      reviewerID  rating        date
# 0        0001393774  A171I27YBM4FL6     5.0  2016-04-29
# 1        0001393774  A1H1DL4K669VQ9     5.0  2016-04-29
# 2        0001393774  A23WIHT5886G36     5.0  2016-04-19
# 3        0001393774  A3SZNOJP8OL26X     5.0  2016-03-30
# 4        0001393774  A3V5XBBT7OZG5G     5.0  2016-02-23
# ...             ...             ...     ...         ...
# 4470324  B01HJG3VZI  A1KCWOF28NPM3M     5.0  2017-11-04
# 4470325  B01HJG3UQI   ASOJC2B605GDG     5.0  2017-04-24
# 4470326  B01HJG3UQI  A13EWHP1W5X77J     4.0  2016-12-06
# 4470327  B01HJG3UQI  A1QN6Z2E6M0S2D     5.0  2016-10-13
# 4470328  B01HJHLNIY   AF65C8QK9NNXP     5.0  2016-07-20
#
# [4470329 rows x 4 columns]

# %%
cds_rating.isnull().sum()
# Out:
# asin          0
# reviewerID    0
# rating        0
# date          0
# dtype: int64

# %%
cds_meta = pd.read_csv("CdsVinyl_meta.csv") 
cds_meta
# Out:
#                                        title  \
# 0                     Songs for the Shepherd
# 1            Lift Him Up With Ron Kenoly VHS
# 2                                 I Love You
# 3       Hymns: 16 Classic Hymns for Children
# 4                           Christmas Carols
# ...                                      ...
# 412320                              Furnaces
# 412321                            Night Hawk
# 412322               Original Album Classics
# 412323               Original Album Classics
# 412324                             Americana
#
#                                                  also_buy  \
# 0       ['B0016CP2GS', 'B0000075PB', 'B0000275QQ', 'B0...
# 1              ['6303908845', '6303646611', 'B000008GO1']
# 2                                                      []
# 3       ['B00000DPLJ', 'B000008UPG', 'B00BQH9RKA', 'B0...
# 4                            ['B0010WAC50', 'B00000DPLJ']
# ...                                                   ...
# ...

# %%
cds_merged = cds_rating.merge(cds_meta, how = 'left', on = 'asin')
cds_merged
# Out:
#                asin      reviewerID  rating        date  \
# 0        0001393774  A171I27YBM4FL6     5.0  2016-04-29
# 1        0001393774  A1H1DL4K669VQ9     5.0  2016-04-29
# 2        0001393774  A23WIHT5886G36     5.0  2016-04-19
# 3        0001393774  A3SZNOJP8OL26X     5.0  2016-03-30
# 4        0001393774  A3V5XBBT7OZG5G     5.0  2016-02-23
# ...             ...             ...     ...         ...
# 4470324  B01HJG3VZI  A1KCWOF28NPM3M     5.0  2017-11-04
# 4470325  B01HJG3UQI   ASOJC2B605GDG     5.0  2017-04-24
# 4470326  B01HJG3UQI  A13EWHP1W5X77J     4.0  2016-12-06
# 4470327  B01HJG3UQI  A1QN6Z2E6M0S2D     5.0  2016-10-13
# 4470328  B01HJHLNIY   AF65C8QK9NNXP     5.0  2016-07-20
#
#                            title  \
# 0         Songs for the Shepherd
# 1         Songs for the Shepherd
# 2         Songs for the Shepherd
# 3         Songs for the Shepherd
# 4         Songs for the Shepherd
# ...                          ...
# 4470324  Original Album Classics
# ...

# %%
cds_merged.isnull().sum()
# Out:
# asin                      0
# reviewerID                0
# rating                    0
# date                      0
# title                380673
# also_buy             380503
# brand                380648
# rank                 390531
# also_view            380503
# main_cat             380503
# price               1229815
# primary_category     380503
# sub_cat              380503
# product_type         380503
# dtype: int64

# %%
cds_merged = cds_merged.dropna(subset = "main_cat")
cds_merged
# Out:
#                asin      reviewerID  rating        date  \
# 0        0001393774  A171I27YBM4FL6     5.0  2016-04-29
# 1        0001393774  A1H1DL4K669VQ9     5.0  2016-04-29
# 2        0001393774  A23WIHT5886G36     5.0  2016-04-19
# 3        0001393774  A3SZNOJP8OL26X     5.0  2016-03-30
# 4        0001393774  A3V5XBBT7OZG5G     5.0  2016-02-23
# ...             ...             ...     ...         ...
# 4470324  B01HJG3VZI  A1KCWOF28NPM3M     5.0  2017-11-04
# 4470325  B01HJG3UQI   ASOJC2B605GDG     5.0  2017-04-24
# 4470326  B01HJG3UQI  A13EWHP1W5X77J     4.0  2016-12-06
# 4470327  B01HJG3UQI  A1QN6Z2E6M0S2D     5.0  2016-10-13
# 4470328  B01HJHLNIY   AF65C8QK9NNXP     5.0  2016-07-20
#
#                            title  \
# 0         Songs for the Shepherd
# 1         Songs for the Shepherd
# 2         Songs for the Shepherd
# 3         Songs for the Shepherd
# 4         Songs for the Shepherd
# ...                          ...
# 4470324  Original Album Classics
# ...

# %%
cds_merged.isnull().sum()
# Out:
# asin                     0
# reviewerID               0
# rating                   0
# date                     0
# title                  170
# also_buy                 0
# brand                  145
# rank                 10028
# also_view                0
# main_cat                 0
# price               849312
# primary_category         0
# sub_cat                  0
# product_type             0
# dtype: int64

# %%
cds_merged['title'] = cds_merged['title'].fillna("Unknown")
cds_merged['brand'] = cds_merged['brand'].fillna(cds_merged['brand'].mode()[0])
cds_merged.isnull().sum()
# Out:
# asin                     0
# reviewerID               0
# rating                   0
# date                     0
# title                    0
# also_buy                 0
# brand                    0
# rank                 10028
# also_view                0
# main_cat                 0
# price               849312
# primary_category         0
# sub_cat                  0
# product_type             0
# dtype: int64

# %%
data = [off_merged, cds_merged]
rating = pd.concat(data,ignore_index = True)
rating
# Out:
#                asin      reviewerID  rating        date  \
# 0        0140503528  A2WJLOXXIB7NF3     3.0  2006-11-03
# 1        0140503528  A1RKICUK0GG6VF     5.0  2006-05-09
# 2        0140503528  A1QA5E50M398VW     5.0  2006-03-11
# 3        0140503528  A3N0HBW8IP8CZQ     5.0  2001-01-24
# 4        0140503528  A1K1JW1C5CUSUZ     5.0  2000-07-30
# ...             ...             ...     ...         ...
# 9482000  B01HJG3VZI  A1KCWOF28NPM3M     5.0  2017-11-04
# 9482001  B01HJG3UQI   ASOJC2B605GDG     5.0  2017-04-24
# 9482002  B01HJG3UQI  A13EWHP1W5X77J     4.0  2016-12-06
# 9482003  B01HJG3UQI  A1QN6Z2E6M0S2D     5.0  2016-10-13
# 9482004  B01HJHLNIY   AF65C8QK9NNXP     5.0  2016-07-20
#
#                            title  \
# 0          A Pocket for Corduroy
# 1          A Pocket for Corduroy
# 2          A Pocket for Corduroy
# 3          A Pocket for Corduroy
# 4          A Pocket for Corduroy
# ...                          ...
# 9482000  Original Album Classics
# ...

# %%
rating.isnull().sum()
# Out:
# asin                      0
# reviewerID                0
# rating                    0
# date                      0
# title                     0
# also_buy                  0
# brand                     0
# rank                  48598
# also_view                 0
# main_cat                  0
# price               2279369
# primary_category          0
# sub_cat                   0
# product_type              0
# dtype: int64

# %%
data = rating[['rating','price','rank']]

# %%
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
data = data
imp_mean = IterativeImputer(random_state=0)
imp_mean.fit(data)
IterativeImputer(random_state = 10)
a = imp_mean.transform(data)
a
# Out:
# array([[3.000000e+00, 9.500000e-01, 4.228940e+05],
#        [5.000000e+00, 9.500000e-01, 4.228940e+05],
#        [5.000000e+00, 9.500000e-01, 4.228940e+05],
#        ...,
#        [4.000000e+00, 1.456000e+01, 6.938600e+04],
#        [5.000000e+00, 1.456000e+01, 6.938600e+04],
#        [5.000000e+00, 2.004000e+01, 1.759107e+06]])

# %%
a = pd.DataFrame(a)
a.rename(columns = {0:'overall', 1:"price", 2:"rank"}, inplace = True)
a
# Out:
#          overall  price       rank
# 0            3.0   0.95   422894.0
# 1            5.0   0.95   422894.0
# 2            5.0   0.95   422894.0
# 3            5.0   0.95   422894.0
# 4            5.0   0.95   422894.0
# ...          ...    ...        ...
# 9482000      5.0  17.28     1795.0
# 9482001      5.0  14.56    69386.0
# 9482002      4.0  14.56    69386.0
# 9482003      5.0  14.56    69386.0
# 9482004      5.0  20.04  1759107.0
#
# [9482005 rows x 3 columns]

# %%
rating['price'] = a.price
rating['rank'] = a['rank']

# %%
rating.isnull().sum()
# Out:
# asin                0
# reviewerID          0
# rating              0
# date                0
# title               0
# also_buy            0
# brand               0
# rank                0
# also_view           0
# main_cat            0
# price               0
# primary_category    0
# sub_cat             0
# product_type        0
# dtype: int64

# %%
rating.head()
# Out:
#          asin      reviewerID  rating        date                  title  \
# 0  0140503528  A2WJLOXXIB7NF3     3.0  2006-11-03  A Pocket for Corduroy
# 1  0140503528  A1RKICUK0GG6VF     5.0  2006-05-09  A Pocket for Corduroy
# 2  0140503528  A1QA5E50M398VW     5.0  2006-03-11  A Pocket for Corduroy
# 3  0140503528  A3N0HBW8IP8CZQ     5.0  2001-01-24  A Pocket for Corduroy
# 4  0140503528  A1K1JW1C5CUSUZ     5.0  2000-07-30  A Pocket for Corduroy
#
#                                             also_buy  \
# 0  ['0140501738', '0448421917', '0670063428', '04...
# 1  ['0140501738', '0448421917', '0670063428', '04...
# 2  ['0140501738', '0448421917', '0670063428', '04...
# 3  ['0140501738', '0448421917', '0670063428', '04...
# 4  ['0140501738', '0448421917', '0670063428', '04...
#
#                        brand      rank       also_view         main_cat  \
# 0  ingram book & distributor  422894.0  ['0140501738']  Office Products
# ...

# %%
#rating2 = rating[7868129:]
#rating2
# Out:
#                asin      reviewerID  rating        date  \
# 7868129  B00000143U  A1G3TIVS4RQSEH     5.0  2013-05-17
# 7868130  B00000143U  A1XKI53W1E891T     5.0  2007-07-29
# 7868131  B00000143U  A3GRVGD58ZUXD0     5.0  2006-06-28
# 7868132  B00000143U  A37FXUQ8Y9XAJK     4.0  2002-12-27
# 7868133  B00000143U  A3120BM9AE7W92     5.0  1999-11-10
# ...             ...             ...     ...         ...
# 9482000  B01HJG3VZI  A1KCWOF28NPM3M     5.0  2017-11-04
# 9482001  B01HJG3UQI   ASOJC2B605GDG     5.0  2017-04-24
# 9482002  B01HJG3UQI  A13EWHP1W5X77J     4.0  2016-12-06
# 9482003  B01HJG3UQI  A1QN6Z2E6M0S2D     5.0  2016-10-13
# 9482004  B01HJHLNIY   AF65C8QK9NNXP     5.0  2016-07-20
#
#                            title  \
# 7868129   Complete Piano Music 3
# 7868130   Complete Piano Music 3
# 7868131   Complete Piano Music 3
# 7868132   Complete Piano Music 3
# 7868133   Complete Piano Music 3
# ...                          ...
# 9482000  Original Album Classics
# ...

# %%
#rating.to_csv("final_rating.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 rating.to_csv("final_rating.csv", index = False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
# ...

# %%
#rating2.to_csv("final_rating2.csv", index = False)
